# %% [markdown]
# <h1 style="text-align: center">
# <div style="color: #DD3403; font-size: 60%">Data Science DISCOVERY MicroProject #3</div>
# <span style="">MicroProject: A DataFrame of Your Weather Forecast</span>
# <div style="font-size: 60%;"><a href="https://discovery.cs.illinois.edu/microproject/03-random-weather-forecast/">https://discovery.cs.illinois.edu/microproject/03-dataframe-weather-forecast/</a></div>
# </h1>
#
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Data API: National Weather Service (NWS) Weather Forecast
#
# The National Weather Service allows, for free, "developers access to critical forecasts, alerts, and observations, along with other weather data."  You can find the full documentation of their API at: [https://www.weather.gov/documentation/services-web-api](https://www.weather.gov/documentation/services-web-api).
#
# Since weather data is based on your location, you need to find the latitude and longitude of coordinate of your location!
#
# - One quick way to do this is to pull up [Google Maps](https://maps.google.com/) and **right click** on a location.
# - The first option will be the `latitude, longitude` of the location of your click on the map.  You can click it to copy it to your clipboard!
#
# Once you have your location, add each component to a variable below:

# %%
latitude = 40.10375767973901
longitude = -88.22832211536941

# %% [markdown]
# ### Finding Your Forecast Area
#
# The National Weather Service API provides a `/points/` endpoint that uses the `latitude,longitude` value to return a weather forecast.  The full URL for this endpoint is in the following format:
#
# ```
# https://api.weather.gov/points/LATITUDE,LONGITUDE
# ```
#
# This endpoint also returns a JSON that can only be read in a `typ="series"` format.
#
# - Using pandas, use `pd.read_json` to read the weather for your location.
# - Make sure to replace `LATITUDE` and `LONGITUDE` with your actual latitude and longitude.
# - As part of `read_json`, make sure to include `typ="series"`.
# - For example: `pd.read_json(..., typ="series")`.
#
# Store the result in a variable named `pointsJSON`:

# %%
import pandas as pd
pointsJSON = pd.read_json("https://api.weather.gov/points/40.10375767973901,-88.22832211536941", typ="series")
pointsJSON
# Out:
# @context      [https://geojson.org/geojson-ld/geojson-contex...
# id              https://api.weather.gov/points/40.1038,-88.2283
# type                                                    Feature
# geometry      {'type': 'Point', 'coordinates': [-88.2283, 40...
# properties    {'@id': 'https://api.weather.gov/points/40.103...
# dtype: object

# %% [markdown]
# ### Finding Your Forecast URL
#
# The JSON you just loaded has multiple fields including two fields with data:
#
# - `geometry`, which include the geometric area for the result (you supplied a single point, but weather forecasts are given for areas that can be many square miles)
# - `properties`, which includes all properties about the location you requested
#
# You can inspect the data further by running `df["geometry"]` or `df["properties"]`.  Inspect the **properties** and look for the URL that provides the **hourly forecast**.

# %%
pointsJSON["properties"]
# Out:
# {'@id': 'https://api.weather.gov/points/40.1038,-88.2283',
#  '@type': 'wx:Point',
#  'cwa': 'ILX',
#  'forecastOffice': 'https://api.weather.gov/offices/ILX',
#  'gridId': 'ILX',
#  'gridX': 95,
#  'gridY': 71,
#  'forecast': 'https://api.weather.gov/gridpoints/ILX/95,71/forecast',
#  'forecastHourly': 'https://api.weather.gov/gridpoints/ILX/95,71/forecast/hourly',
#  'forecastGridData': 'https://api.weather.gov/gridpoints/ILX/95,71',
#  'observationStations': 'https://api.weather.gov/gridpoints/ILX/95,71/stations',
#  'relativeLocation': {'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-88.197323, 40.110126]},
#   'properties': {'city': 'Urbana',
#    'state': 'IL',
#    'distance': {'unitCode': 'wmoUnit:m', 'value': 2726.7858878579},
#    'bearing': {'unitCode': 'wmoUnit:degree_(angle)', 'value': 255}}},
#  'forecastZone': 'https://api.weather.gov/zones/forecast/ILZ045',
#  'county': 'https://api.weather.gov/zones/county/ILC019',
#  'fireWeatherZone': 'https://api.weather.gov/zones/fire/ILZ045',
#  'timeZone': 'America/Chicago',
#  'radarStation': 'KILX'}

# %% [markdown]
# ### Record Your Forecast URL
#
# Finally, record the URL that you can use to find the hourly forecast for your location:

# %%
hourlyForecastURL = "https://api.weather.gov/gridpoints/ILX/95,71/forecast/hourly"
hourlyForecastURL
# Out:
# 'https://api.weather.gov/gridpoints/ILX/95,71/forecast/hourly'

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 1: Loading Your Weather Forecast as a DataFrame
#
# In the same way as you did in the beginning of this MicroProject, use the hourlyForecastURL and `pd.read_json` to load the your weather forecast.  Store your result in the variable `forecastJSON`:

# %%
forecastJSON = pd.read_json("https://api.weather.gov/gridpoints/ILX/95,71/forecast/hourly",typ="series")
forecastJSON
# Out:
# @context      [https://geojson.org/geojson-ld/geojson-contex...
# type                                                    Feature
# geometry      {'type': 'Polygon', 'coordinates': [[[-88.2476...
# properties    {'updated': '2022-09-21T17:42:53+00:00', 'unit...
# dtype: object

# %% [markdown]
# ### Finding the Forecast Data
#
# Inside of the `properties` data within `forecastJSON`, the `periods` data provides a **well-defined, structured** set of data that contains the forecast for every hour for your location.
#
# Check out how it looks in the raw form:

# %%
forecastJSON["properties"]["periods"]
# Out:
# [{'number': 1,
#   'name': '',
#   'startTime': '2022-09-21T13:00:00-05:00',
#   'endTime': '2022-09-21T14:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 91,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '10 mph',
#   'windDirection': 'W',
#   'icon': 'https://api.weather.gov/icons/land/day/tsra_hi,40?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 2,
#   'name': '',
#   'startTime': '2022-09-21T14:00:00-05:00',
#   'endTime': '2022-09-21T15:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 90,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '9 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/tsra_sct,40?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 3,
#   'name': '',
#   'startTime': '2022-09-21T15:00:00-05:00',
#   'endTime': '2022-09-21T16:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 89,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '9 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/tsra_hi,40?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 4,
#   'name': '',
#   'startTime': '2022-09-21T16:00:00-05:00',
#   'endTime': '2022-09-21T17:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 86,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '9 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/tsra_sct,40?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 5,
#   'name': '',
#   'startTime': '2022-09-21T17:00:00-05:00',
#   'endTime': '2022-09-21T18:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 82,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '10 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/tsra,40?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 6,
#   'name': '',
#   'startTime': '2022-09-21T18:00:00-05:00',
#   'endTime': '2022-09-21T19:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 80,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '13 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/tsra,30?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 7,
#   'name': '',
#   'startTime': '2022-09-21T19:00:00-05:00',
#   'endTime': '2022-09-21T20:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 77,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '14 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/tsra_sct,30?size=small',
#   'shortForecast': 'Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 8,
#   'name': '',
#   'startTime': '2022-09-21T20:00:00-05:00',
#   'endTime': '2022-09-21T21:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 73,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '15 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/tsra_sct?size=small',
#   'shortForecast': 'Slight Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 9,
#   'name': '',
#   'startTime': '2022-09-21T21:00:00-05:00',
#   'endTime': '2022-09-21T22:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 71,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '14 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/tsra_sct?size=small',
#   'shortForecast': 'Slight Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 10,
#   'name': '',
#   'startTime': '2022-09-21T22:00:00-05:00',
#   'endTime': '2022-09-21T23:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 69,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '14 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/tsra?size=small',
#   'shortForecast': 'Slight Chance Showers And Thunderstorms',
#   'detailedForecast': ''},
#  {'number': 11,
#   'name': '',
#   'startTime': '2022-09-21T23:00:00-05:00',
#   'endTime': '2022-09-22T00:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 67,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '14 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 12,
#   'name': '',
#   'startTime': '2022-09-22T00:00:00-05:00',
#   'endTime': '2022-09-22T01:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 65,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '14 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/bkn?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 13,
#   'name': '',
#   'startTime': '2022-09-22T01:00:00-05:00',
#   'endTime': '2022-09-22T02:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 63,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '14 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 14,
#   'name': '',
#   'startTime': '2022-09-22T02:00:00-05:00',
#   'endTime': '2022-09-22T03:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 63,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '13 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/bkn?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 15,
#   'name': '',
#   'startTime': '2022-09-22T03:00:00-05:00',
#   'endTime': '2022-09-22T04:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 61,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '12 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 16,
#   'name': '',
#   'startTime': '2022-09-22T04:00:00-05:00',
#   'endTime': '2022-09-22T05:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 59,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '10 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 17,
#   'name': '',
#   'startTime': '2022-09-22T05:00:00-05:00',
#   'endTime': '2022-09-22T06:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 58,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '10 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 18,
#   'name': '',
#   'startTime': '2022-09-22T06:00:00-05:00',
#   'endTime': '2022-09-22T07:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 57,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '9 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 19,
#   'name': '',
#   'startTime': '2022-09-22T07:00:00-05:00',
#   'endTime': '2022-09-22T08:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 56,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '9 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 20,
#   'name': '',
#   'startTime': '2022-09-22T08:00:00-05:00',
#   'endTime': '2022-09-22T09:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 57,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '10 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 21,
#   'name': '',
#   'startTime': '2022-09-22T09:00:00-05:00',
#   'endTime': '2022-09-22T10:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 58,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '12 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 22,
#   'name': '',
#   'startTime': '2022-09-22T10:00:00-05:00',
#   'endTime': '2022-09-22T11:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 60,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '13 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 23,
#   'name': '',
#   'startTime': '2022-09-22T11:00:00-05:00',
#   'endTime': '2022-09-22T12:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 62,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '13 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 24,
#   'name': '',
#   'startTime': '2022-09-22T12:00:00-05:00',
#   'endTime': '2022-09-22T13:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 64,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '13 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 25,
#   'name': '',
#   'startTime': '2022-09-22T13:00:00-05:00',
#   'endTime': '2022-09-22T14:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 65,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '14 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 26,
#   'name': '',
#   'startTime': '2022-09-22T14:00:00-05:00',
#   'endTime': '2022-09-22T15:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 65,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '14 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 27,
#   'name': '',
#   'startTime': '2022-09-22T15:00:00-05:00',
#   'endTime': '2022-09-22T16:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 66,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '14 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 28,
#   'name': '',
#   'startTime': '2022-09-22T16:00:00-05:00',
#   'endTime': '2022-09-22T17:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 66,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '13 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 29,
#   'name': '',
#   'startTime': '2022-09-22T17:00:00-05:00',
#   'endTime': '2022-09-22T18:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 64,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '12 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 30,
#   'name': '',
#   'startTime': '2022-09-22T18:00:00-05:00',
#   'endTime': '2022-09-22T19:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 62,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '10 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 31,
#   'name': '',
#   'startTime': '2022-09-22T19:00:00-05:00',
#   'endTime': '2022-09-22T20:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 60,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '8 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 32,
#   'name': '',
#   'startTime': '2022-09-22T20:00:00-05:00',
#   'endTime': '2022-09-22T21:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 57,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '7 mph',
#   'windDirection': 'NNE',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 33,
#   'name': '',
#   'startTime': '2022-09-22T21:00:00-05:00',
#   'endTime': '2022-09-22T22:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 54,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '7 mph',
#   'windDirection': 'NNE',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 34,
#   'name': '',
#   'startTime': '2022-09-22T22:00:00-05:00',
#   'endTime': '2022-09-22T23:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 52,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 35,
#   'name': '',
#   'startTime': '2022-09-22T23:00:00-05:00',
#   'endTime': '2022-09-23T00:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 51,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 36,
#   'name': '',
#   'startTime': '2022-09-23T00:00:00-05:00',
#   'endTime': '2022-09-23T01:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 50,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 37,
#   'name': '',
#   'startTime': '2022-09-23T01:00:00-05:00',
#   'endTime': '2022-09-23T02:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 50,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '3 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 38,
#   'name': '',
#   'startTime': '2022-09-23T02:00:00-05:00',
#   'endTime': '2022-09-23T03:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 49,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '3 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 39,
#   'name': '',
#   'startTime': '2022-09-23T03:00:00-05:00',
#   'endTime': '2022-09-23T04:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 48,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '3 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 40,
#   'name': '',
#   'startTime': '2022-09-23T04:00:00-05:00',
#   'endTime': '2022-09-23T05:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 47,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '3 mph',
#   'windDirection': 'NE',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 41,
#   'name': '',
#   'startTime': '2022-09-23T05:00:00-05:00',
#   'endTime': '2022-09-23T06:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 46,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '3 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 42,
#   'name': '',
#   'startTime': '2022-09-23T06:00:00-05:00',
#   'endTime': '2022-09-23T07:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 45,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '3 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 43,
#   'name': '',
#   'startTime': '2022-09-23T07:00:00-05:00',
#   'endTime': '2022-09-23T08:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 46,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '3 mph',
#   'windDirection': 'ENE',
#   'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 44,
#   'name': '',
#   'startTime': '2022-09-23T08:00:00-05:00',
#   'endTime': '2022-09-23T09:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 48,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'E',
#   'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 45,
#   'name': '',
#   'startTime': '2022-09-23T09:00:00-05:00',
#   'endTime': '2022-09-23T10:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 52,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'E',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 46,
#   'name': '',
#   'startTime': '2022-09-23T10:00:00-05:00',
#   'endTime': '2022-09-23T11:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 55,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'ESE',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 47,
#   'name': '',
#   'startTime': '2022-09-23T11:00:00-05:00',
#   'endTime': '2022-09-23T12:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 58,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'ESE',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 48,
#   'name': '',
#   'startTime': '2022-09-23T12:00:00-05:00',
#   'endTime': '2022-09-23T13:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 60,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'ESE',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 49,
#   'name': '',
#   'startTime': '2022-09-23T13:00:00-05:00',
#   'endTime': '2022-09-23T14:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 62,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'ESE',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 50,
#   'name': '',
#   'startTime': '2022-09-23T14:00:00-05:00',
#   'endTime': '2022-09-23T15:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 63,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'SE',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 51,
#   'name': '',
#   'startTime': '2022-09-23T15:00:00-05:00',
#   'endTime': '2022-09-23T16:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 63,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'SE',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 52,
#   'name': '',
#   'startTime': '2022-09-23T16:00:00-05:00',
#   'endTime': '2022-09-23T17:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 62,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'SSE',
#   'icon': 'https://api.weather.gov/icons/land/day/ovc?size=small',
#   'shortForecast': 'Cloudy',
#   'detailedForecast': ''},
#  {'number': 53,
#   'name': '',
#   'startTime': '2022-09-23T17:00:00-05:00',
#   'endTime': '2022-09-23T18:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 61,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'SSE',
#   'icon': 'https://api.weather.gov/icons/land/day/ovc?size=small',
#   'shortForecast': 'Cloudy',
#   'detailedForecast': ''},
#  {'number': 54,
#   'name': '',
#   'startTime': '2022-09-23T18:00:00-05:00',
#   'endTime': '2022-09-23T19:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 60,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'SSE',
#   'icon': 'https://api.weather.gov/icons/land/night/ovc?size=small',
#   'shortForecast': 'Cloudy',
#   'detailedForecast': ''},
#  {'number': 55,
#   'name': '',
#   'startTime': '2022-09-23T19:00:00-05:00',
#   'endTime': '2022-09-23T20:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 59,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '3 mph',
#   'windDirection': 'SSE',
#   'icon': 'https://api.weather.gov/icons/land/night/rain_showers?size=small',
#   'shortForecast': 'Slight Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 56,
#   'name': '',
#   'startTime': '2022-09-23T20:00:00-05:00',
#   'endTime': '2022-09-23T21:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 58,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '3 mph',
#   'windDirection': 'SSE',
#   'icon': 'https://api.weather.gov/icons/land/night/rain_showers?size=small',
#   'shortForecast': 'Slight Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 57,
#   'name': '',
#   'startTime': '2022-09-23T21:00:00-05:00',
#   'endTime': '2022-09-23T22:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 56,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '3 mph',
#   'windDirection': 'SE',
#   'icon': 'https://api.weather.gov/icons/land/night/rain_showers?size=small',
#   'shortForecast': 'Slight Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 58,
#   'name': '',
#   'startTime': '2022-09-23T22:00:00-05:00',
#   'endTime': '2022-09-23T23:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 55,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '3 mph',
#   'windDirection': 'SE',
#   'icon': 'https://api.weather.gov/icons/land/night/rain_showers?size=small',
#   'shortForecast': 'Slight Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 59,
#   'name': '',
#   'startTime': '2022-09-23T23:00:00-05:00',
#   'endTime': '2022-09-24T00:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 55,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '3 mph',
#   'windDirection': 'SE',
#   'icon': 'https://api.weather.gov/icons/land/night/rain_showers?size=small',
#   'shortForecast': 'Slight Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 60,
#   'name': '',
#   'startTime': '2022-09-24T00:00:00-05:00',
#   'endTime': '2022-09-24T01:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 55,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'SSE',
#   'icon': 'https://api.weather.gov/icons/land/night/rain_showers?size=small',
#   'shortForecast': 'Slight Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 61,
#   'name': '',
#   'startTime': '2022-09-24T01:00:00-05:00',
#   'endTime': '2022-09-24T02:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 55,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'SSE',
#   'icon': 'https://api.weather.gov/icons/land/night/rain_showers?size=small',
#   'shortForecast': 'Slight Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 62,
#   'name': '',
#   'startTime': '2022-09-24T02:00:00-05:00',
#   'endTime': '2022-09-24T03:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 55,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'SSE',
#   'icon': 'https://api.weather.gov/icons/land/night/rain_showers?size=small',
#   'shortForecast': 'Slight Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 63,
#   'name': '',
#   'startTime': '2022-09-24T03:00:00-05:00',
#   'endTime': '2022-09-24T04:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 55,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'SSE',
#   'icon': 'https://api.weather.gov/icons/land/night/rain_showers?size=small',
#   'shortForecast': 'Slight Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 64,
#   'name': '',
#   'startTime': '2022-09-24T04:00:00-05:00',
#   'endTime': '2022-09-24T05:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 55,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'SSE',
#   'icon': 'https://api.weather.gov/icons/land/night/rain_showers?size=small',
#   'shortForecast': 'Slight Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 65,
#   'name': '',
#   'startTime': '2022-09-24T05:00:00-05:00',
#   'endTime': '2022-09-24T06:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 55,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'SSE',
#   'icon': 'https://api.weather.gov/icons/land/night/rain_showers?size=small',
#   'shortForecast': 'Slight Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 66,
#   'name': '',
#   'startTime': '2022-09-24T06:00:00-05:00',
#   'endTime': '2022-09-24T07:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 55,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '7 mph',
#   'windDirection': 'S',
#   'icon': 'https://api.weather.gov/icons/land/day/rain_showers?size=small',
#   'shortForecast': 'Slight Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 67,
#   'name': '',
#   'startTime': '2022-09-24T07:00:00-05:00',
#   'endTime': '2022-09-24T08:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 56,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '7 mph',
#   'windDirection': 'S',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 68,
#   'name': '',
#   'startTime': '2022-09-24T08:00:00-05:00',
#   'endTime': '2022-09-24T09:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 58,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '8 mph',
#   'windDirection': 'S',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 69,
#   'name': '',
#   'startTime': '2022-09-24T09:00:00-05:00',
#   'endTime': '2022-09-24T10:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 62,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '9 mph',
#   'windDirection': 'S',
#   'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 70,
#   'name': '',
#   'startTime': '2022-09-24T10:00:00-05:00',
#   'endTime': '2022-09-24T11:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 65,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '10 mph',
#   'windDirection': 'SSW',
#   'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 71,
#   'name': '',
#   'startTime': '2022-09-24T11:00:00-05:00',
#   'endTime': '2022-09-24T12:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 68,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '12 mph',
#   'windDirection': 'SSW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 72,
#   'name': '',
#   'startTime': '2022-09-24T12:00:00-05:00',
#   'endTime': '2022-09-24T13:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 71,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '12 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 73,
#   'name': '',
#   'startTime': '2022-09-24T13:00:00-05:00',
#   'endTime': '2022-09-24T14:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 73,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '12 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 74,
#   'name': '',
#   'startTime': '2022-09-24T14:00:00-05:00',
#   'endTime': '2022-09-24T15:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 75,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '12 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 75,
#   'name': '',
#   'startTime': '2022-09-24T15:00:00-05:00',
#   'endTime': '2022-09-24T16:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 75,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '12 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 76,
#   'name': '',
#   'startTime': '2022-09-24T16:00:00-05:00',
#   'endTime': '2022-09-24T17:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 75,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '12 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 77,
#   'name': '',
#   'startTime': '2022-09-24T17:00:00-05:00',
#   'endTime': '2022-09-24T18:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 74,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '10 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 78,
#   'name': '',
#   'startTime': '2022-09-24T18:00:00-05:00',
#   'endTime': '2022-09-24T19:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 72,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '8 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 79,
#   'name': '',
#   'startTime': '2022-09-24T19:00:00-05:00',
#   'endTime': '2022-09-24T20:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 70,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '7 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 80,
#   'name': '',
#   'startTime': '2022-09-24T20:00:00-05:00',
#   'endTime': '2022-09-24T21:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 68,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 81,
#   'name': '',
#   'startTime': '2022-09-24T21:00:00-05:00',
#   'endTime': '2022-09-24T22:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 66,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 82,
#   'name': '',
#   'startTime': '2022-09-24T22:00:00-05:00',
#   'endTime': '2022-09-24T23:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 64,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'SW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 83,
#   'name': '',
#   'startTime': '2022-09-24T23:00:00-05:00',
#   'endTime': '2022-09-25T00:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 63,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'WSW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 84,
#   'name': '',
#   'startTime': '2022-09-25T00:00:00-05:00',
#   'endTime': '2022-09-25T01:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 62,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'WSW',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 85,
#   'name': '',
#   'startTime': '2022-09-25T01:00:00-05:00',
#   'endTime': '2022-09-25T02:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 62,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'WSW',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 86,
#   'name': '',
#   'startTime': '2022-09-25T02:00:00-05:00',
#   'endTime': '2022-09-25T03:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 61,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'W',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 87,
#   'name': '',
#   'startTime': '2022-09-25T03:00:00-05:00',
#   'endTime': '2022-09-25T04:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 61,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'W',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 88,
#   'name': '',
#   'startTime': '2022-09-25T04:00:00-05:00',
#   'endTime': '2022-09-25T05:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 60,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'W',
#   'icon': 'https://api.weather.gov/icons/land/night/sct?size=small',
#   'shortForecast': 'Partly Cloudy',
#   'detailedForecast': ''},
#  {'number': 89,
#   'name': '',
#   'startTime': '2022-09-25T05:00:00-05:00',
#   'endTime': '2022-09-25T06:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 59,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'W',
#   'icon': 'https://api.weather.gov/icons/land/night/bkn?size=small',
#   'shortForecast': 'Mostly Cloudy',
#   'detailedForecast': ''},
#  {'number': 90,
#   'name': '',
#   'startTime': '2022-09-25T06:00:00-05:00',
#   'endTime': '2022-09-25T07:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 59,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 91,
#   'name': '',
#   'startTime': '2022-09-25T07:00:00-05:00',
#   'endTime': '2022-09-25T08:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 59,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 92,
#   'name': '',
#   'startTime': '2022-09-25T08:00:00-05:00',
#   'endTime': '2022-09-25T09:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 61,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '7 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/bkn?size=small',
#   'shortForecast': 'Partly Sunny',
#   'detailedForecast': ''},
#  {'number': 93,
#   'name': '',
#   'startTime': '2022-09-25T09:00:00-05:00',
#   'endTime': '2022-09-25T10:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 63,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '8 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 94,
#   'name': '',
#   'startTime': '2022-09-25T10:00:00-05:00',
#   'endTime': '2022-09-25T11:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 66,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '10 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 95,
#   'name': '',
#   'startTime': '2022-09-25T11:00:00-05:00',
#   'endTime': '2022-09-25T12:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 68,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '13 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 96,
#   'name': '',
#   'startTime': '2022-09-25T12:00:00-05:00',
#   'endTime': '2022-09-25T13:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 71,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '14 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/sct?size=small',
#   'shortForecast': 'Mostly Sunny',
#   'detailedForecast': ''},
#  {'number': 97,
#   'name': '',
#   'startTime': '2022-09-25T13:00:00-05:00',
#   'endTime': '2022-09-25T14:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 72,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '15 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/rain_showers?size=small',
#   'shortForecast': 'Slight Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 98,
#   'name': '',
#   'startTime': '2022-09-25T14:00:00-05:00',
#   'endTime': '2022-09-25T15:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 72,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '15 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/rain_showers?size=small',
#   'shortForecast': 'Slight Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 99,
#   'name': '',
#   'startTime': '2022-09-25T15:00:00-05:00',
#   'endTime': '2022-09-25T16:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 72,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '15 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/rain_showers?size=small',
#   'shortForecast': 'Slight Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 100,
#   'name': '',
#   'startTime': '2022-09-25T16:00:00-05:00',
#   'endTime': '2022-09-25T17:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 71,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '15 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/rain_showers?size=small',
#   'shortForecast': 'Slight Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 101,
#   'name': '',
#   'startTime': '2022-09-25T17:00:00-05:00',
#   'endTime': '2022-09-25T18:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 70,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '15 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/rain_showers?size=small',
#   'shortForecast': 'Slight Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 102,
#   'name': '',
#   'startTime': '2022-09-25T18:00:00-05:00',
#   'endTime': '2022-09-25T19:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 68,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '14 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/rain_showers?size=small',
#   'shortForecast': 'Slight Chance Rain Showers',
#   'detailedForecast': ''},
#  {'number': 103,
#   'name': '',
#   'startTime': '2022-09-25T19:00:00-05:00',
#   'endTime': '2022-09-25T20:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 66,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '13 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 104,
#   'name': '',
#   'startTime': '2022-09-25T20:00:00-05:00',
#   'endTime': '2022-09-25T21:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 64,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '12 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 105,
#   'name': '',
#   'startTime': '2022-09-25T21:00:00-05:00',
#   'endTime': '2022-09-25T22:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 61,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '10 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 106,
#   'name': '',
#   'startTime': '2022-09-25T22:00:00-05:00',
#   'endTime': '2022-09-25T23:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 59,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '9 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 107,
#   'name': '',
#   'startTime': '2022-09-25T23:00:00-05:00',
#   'endTime': '2022-09-26T00:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 58,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '8 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 108,
#   'name': '',
#   'startTime': '2022-09-26T00:00:00-05:00',
#   'endTime': '2022-09-26T01:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 57,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '7 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 109,
#   'name': '',
#   'startTime': '2022-09-26T01:00:00-05:00',
#   'endTime': '2022-09-26T02:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 56,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '7 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 110,
#   'name': '',
#   'startTime': '2022-09-26T02:00:00-05:00',
#   'endTime': '2022-09-26T03:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 55,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '7 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 111,
#   'name': '',
#   'startTime': '2022-09-26T03:00:00-05:00',
#   'endTime': '2022-09-26T04:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 55,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '7 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 112,
#   'name': '',
#   'startTime': '2022-09-26T04:00:00-05:00',
#   'endTime': '2022-09-26T05:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 54,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '7 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 113,
#   'name': '',
#   'startTime': '2022-09-26T05:00:00-05:00',
#   'endTime': '2022-09-26T06:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 53,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '7 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 114,
#   'name': '',
#   'startTime': '2022-09-26T06:00:00-05:00',
#   'endTime': '2022-09-26T07:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 52,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '7 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 115,
#   'name': '',
#   'startTime': '2022-09-26T07:00:00-05:00',
#   'endTime': '2022-09-26T08:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 52,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '7 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 116,
#   'name': '',
#   'startTime': '2022-09-26T08:00:00-05:00',
#   'endTime': '2022-09-26T09:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 54,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '8 mph',
#   'windDirection': 'WNW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 117,
#   'name': '',
#   'startTime': '2022-09-26T09:00:00-05:00',
#   'endTime': '2022-09-26T10:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 57,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '10 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 118,
#   'name': '',
#   'startTime': '2022-09-26T10:00:00-05:00',
#   'endTime': '2022-09-26T11:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 60,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '12 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 119,
#   'name': '',
#   'startTime': '2022-09-26T11:00:00-05:00',
#   'endTime': '2022-09-26T12:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 62,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '13 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 120,
#   'name': '',
#   'startTime': '2022-09-26T12:00:00-05:00',
#   'endTime': '2022-09-26T13:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 64,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '14 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 121,
#   'name': '',
#   'startTime': '2022-09-26T13:00:00-05:00',
#   'endTime': '2022-09-26T14:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 66,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '14 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 122,
#   'name': '',
#   'startTime': '2022-09-26T14:00:00-05:00',
#   'endTime': '2022-09-26T15:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 67,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '14 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 123,
#   'name': '',
#   'startTime': '2022-09-26T15:00:00-05:00',
#   'endTime': '2022-09-26T16:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 68,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '14 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 124,
#   'name': '',
#   'startTime': '2022-09-26T16:00:00-05:00',
#   'endTime': '2022-09-26T17:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 68,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '14 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 125,
#   'name': '',
#   'startTime': '2022-09-26T17:00:00-05:00',
#   'endTime': '2022-09-26T18:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 67,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '13 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 126,
#   'name': '',
#   'startTime': '2022-09-26T18:00:00-05:00',
#   'endTime': '2022-09-26T19:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 64,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '12 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 127,
#   'name': '',
#   'startTime': '2022-09-26T19:00:00-05:00',
#   'endTime': '2022-09-26T20:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 62,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '10 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 128,
#   'name': '',
#   'startTime': '2022-09-26T20:00:00-05:00',
#   'endTime': '2022-09-26T21:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 60,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '9 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 129,
#   'name': '',
#   'startTime': '2022-09-26T21:00:00-05:00',
#   'endTime': '2022-09-26T22:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 58,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '7 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 130,
#   'name': '',
#   'startTime': '2022-09-26T22:00:00-05:00',
#   'endTime': '2022-09-26T23:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 56,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 131,
#   'name': '',
#   'startTime': '2022-09-26T23:00:00-05:00',
#   'endTime': '2022-09-27T00:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 54,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 132,
#   'name': '',
#   'startTime': '2022-09-27T00:00:00-05:00',
#   'endTime': '2022-09-27T01:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 53,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 133,
#   'name': '',
#   'startTime': '2022-09-27T01:00:00-05:00',
#   'endTime': '2022-09-27T02:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 52,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 134,
#   'name': '',
#   'startTime': '2022-09-27T02:00:00-05:00',
#   'endTime': '2022-09-27T03:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 51,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 135,
#   'name': '',
#   'startTime': '2022-09-27T03:00:00-05:00',
#   'endTime': '2022-09-27T04:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 51,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 136,
#   'name': '',
#   'startTime': '2022-09-27T04:00:00-05:00',
#   'endTime': '2022-09-27T05:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 50,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 137,
#   'name': '',
#   'startTime': '2022-09-27T05:00:00-05:00',
#   'endTime': '2022-09-27T06:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 49,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 138,
#   'name': '',
#   'startTime': '2022-09-27T06:00:00-05:00',
#   'endTime': '2022-09-27T07:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 48,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 139,
#   'name': '',
#   'startTime': '2022-09-27T07:00:00-05:00',
#   'endTime': '2022-09-27T08:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 48,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 140,
#   'name': '',
#   'startTime': '2022-09-27T08:00:00-05:00',
#   'endTime': '2022-09-27T09:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 51,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '7 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 141,
#   'name': '',
#   'startTime': '2022-09-27T09:00:00-05:00',
#   'endTime': '2022-09-27T10:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 55,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '8 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 142,
#   'name': '',
#   'startTime': '2022-09-27T10:00:00-05:00',
#   'endTime': '2022-09-27T11:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 59,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '9 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 143,
#   'name': '',
#   'startTime': '2022-09-27T11:00:00-05:00',
#   'endTime': '2022-09-27T12:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 62,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '10 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 144,
#   'name': '',
#   'startTime': '2022-09-27T12:00:00-05:00',
#   'endTime': '2022-09-27T13:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 64,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '10 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 145,
#   'name': '',
#   'startTime': '2022-09-27T13:00:00-05:00',
#   'endTime': '2022-09-27T14:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 65,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '10 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 146,
#   'name': '',
#   'startTime': '2022-09-27T14:00:00-05:00',
#   'endTime': '2022-09-27T15:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 66,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '10 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 147,
#   'name': '',
#   'startTime': '2022-09-27T15:00:00-05:00',
#   'endTime': '2022-09-27T16:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 66,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '10 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 148,
#   'name': '',
#   'startTime': '2022-09-27T16:00:00-05:00',
#   'endTime': '2022-09-27T17:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 66,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '10 mph',
#   'windDirection': 'NW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 149,
#   'name': '',
#   'startTime': '2022-09-27T17:00:00-05:00',
#   'endTime': '2022-09-27T18:00:00-05:00',
#   'isDaytime': True,
#   'temperature': 65,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '9 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/day/few?size=small',
#   'shortForecast': 'Sunny',
#   'detailedForecast': ''},
#  {'number': 150,
#   'name': '',
#   'startTime': '2022-09-27T18:00:00-05:00',
#   'endTime': '2022-09-27T19:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 63,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '7 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 151,
#   'name': '',
#   'startTime': '2022-09-27T19:00:00-05:00',
#   'endTime': '2022-09-27T20:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 61,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '6 mph',
#   'windDirection': 'NNW',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 152,
#   'name': '',
#   'startTime': '2022-09-27T20:00:00-05:00',
#   'endTime': '2022-09-27T21:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 58,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 153,
#   'name': '',
#   'startTime': '2022-09-27T21:00:00-05:00',
#   'endTime': '2022-09-27T22:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 56,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 154,
#   'name': '',
#   'startTime': '2022-09-27T22:00:00-05:00',
#   'endTime': '2022-09-27T23:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 53,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 155,
#   'name': '',
#   'startTime': '2022-09-27T23:00:00-05:00',
#   'endTime': '2022-09-28T00:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 51,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '5 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/night/few?size=small',
#   'shortForecast': 'Mostly Clear',
#   'detailedForecast': ''},
#  {'number': 156,
#   'name': '',
#   'startTime': '2022-09-28T00:00:00-05:00',
#   'endTime': '2022-09-28T01:00:00-05:00',
#   'isDaytime': False,
#   'temperature': 50,
#   'temperatureUnit': 'F',
#   'temperatureTrend': None,
#   'windSpeed': '3 mph',
#   'windDirection': 'N',
#   'icon': 'https://api.weather.gov/icons/land/night/skc?size=small',
#   'shortForecast': 'Clear',
#   'detailedForecast': ''}]

# %% [markdown]
# ### Loading the Data at a DataFrame
#
# Since we have **clean, structured data**, we can read it into pandas!  The code below creates a DataFrame out of the above data by using the `pd.DataFrame` command:

# %%
df = pd.DataFrame(forecastJSON["properties"]["periods"])
df
# Out:
#      number name                  startTime                    endTime  \
# 0         1       2022-09-21T13:00:00-05:00  2022-09-21T14:00:00-05:00
# 1         2       2022-09-21T14:00:00-05:00  2022-09-21T15:00:00-05:00
# 2         3       2022-09-21T15:00:00-05:00  2022-09-21T16:00:00-05:00
# 3         4       2022-09-21T16:00:00-05:00  2022-09-21T17:00:00-05:00
# 4         5       2022-09-21T17:00:00-05:00  2022-09-21T18:00:00-05:00
# ..      ...  ...                        ...                        ...
# 151     152       2022-09-27T20:00:00-05:00  2022-09-27T21:00:00-05:00
# 152     153       2022-09-27T21:00:00-05:00  2022-09-27T22:00:00-05:00
# 153     154       2022-09-27T22:00:00-05:00  2022-09-27T23:00:00-05:00
# 154     155       2022-09-27T23:00:00-05:00  2022-09-28T00:00:00-05:00
# 155     156       2022-09-28T00:00:00-05:00  2022-09-28T01:00:00-05:00
#
#      isDaytime  temperature temperatureUnit temperatureTrend windSpeed  \
# 0         True           91               F             None    10 mph
# 1         True           90               F             None     9 mph
# 2         True           89               F             None     9 mph
# 3         True           86               F             None     9 mph
# 4         True           82               F             None    10 mph
# ..         ...          ...             ...              ...       ...
# 151      False           58               F             None     5 mph
# 152      False           56               F             None     5 mph
# 153      False           53               F             None     5 mph
# 154      False           51               F             None     5 mph
# 155      False           50               F             None     3 mph
#
#     windDirection                                               icon  \
# 0               W  https://api.weather.gov/icons/land/day/tsra_hi...
# 1             WNW  https://api.weather.gov/icons/land/day/tsra_sc...
# 2              NW  https://api.weather.gov/icons/land/day/tsra_hi...
# 3              NW  https://api.weather.gov/icons/land/day/tsra_sc...
# 4              NW  https://api.weather.gov/icons/land/day/tsra,40...
# ..            ...                                                ...
# 151             N  https://api.weather.gov/icons/land/night/few?s...
# 152             N  https://api.weather.gov/icons/land/night/few?s...
# 153             N  https://api.weather.gov/icons/land/night/few?s...
# 154             N  https://api.weather.gov/icons/land/night/few?s...
# 155             N  https://api.weather.gov/icons/land/night/skc?s...
#
#                         shortForecast detailedForecast
# 0    Chance Showers And Thunderstorms
# 1    Chance Showers And Thunderstorms
# 2    Chance Showers And Thunderstorms
# 3    Chance Showers And Thunderstorms
# 4    Chance Showers And Thunderstorms
# ..                                ...              ...
# 151                      Mostly Clear
# 152                      Mostly Clear
# 153                      Mostly Clear
# 154                      Mostly Clear
# 155                             Clear
#
# [156 rows x 13 columns]

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 2: Exploring Your Weather
#
# Now that you have the weather forecast for **your location** loaded into the DataFrame `df`, it's time to nerd out with it!

# %% [markdown]
# ### Your Warmest Upcoming Temperature
#
# Using your data, find the warmest temperature in the entire forecast!  Save that row as `df_warmest`:

# %%
df_warmest = df.nlargest(1, "temperature")
df_warmest
# Out:
#    number name                  startTime                    endTime  \
# 0       1       2022-09-21T13:00:00-05:00  2022-09-21T14:00:00-05:00
#
#    isDaytime  temperature temperatureUnit temperatureTrend windSpeed  \
# 0       True           91               F             None    10 mph
#
#   windDirection                                               icon  \
# 0             W  https://api.weather.gov/icons/land/day/tsra_hi...
#
#                       shortForecast detailedForecast
# 0  Chance Showers And Thunderstorms

# %% [markdown]
# ### Your Coldest Upcoming Temperature
#
# Using your data, find the coldest temperature in the entire forecast!  Save that row as `df_coldest`:

# %%
df_coldest = df.nsmallest(1, "temperature")
df_coldest
# Out:
#     number name                  startTime                    endTime  \
# 41      42       2022-09-23T06:00:00-05:00  2022-09-23T07:00:00-05:00
#
#     isDaytime  temperature temperatureUnit temperatureTrend windSpeed  \
# 41       True           45               F             None     3 mph
#
#    windDirection                                               icon  \
# 41           ENE  https://api.weather.gov/icons/land/day/sct?siz...
#
#    shortForecast detailedForecast
# 41  Mostly Sunny

# %% [markdown]
# ### Hours of Sky Conditions
#
# The `shortForecast` column provides a brief summary of the forecasted condition of the sky for each hour.  Create a DataFrame that contains a summary of upcoming sky conditions in only two columns:
#
# - `shortForecast`, and
# - `count`, containing the number of times that `shortForecast` appears in the forecast
#
# Save the summary in the `skySummary` variable:

# %%
skySummary = df.groupby("shortForecast").agg("count").reset_index()
skySummary["count"] = skySummary["name"]
skySummary = skySummary.iloc[:, [0, 13]]
skySummary
# Out:
#                               shortForecast  count
# 0          Chance Showers And Thunderstorms      7
# 1                                     Clear      1
# 2                                    Cloudy      3
# 3                              Mostly Clear     35
# 4                             Mostly Cloudy      6
# 5                              Mostly Sunny     17
# 6                             Partly Cloudy     22
# 7                              Partly Sunny      9
# 8                Slight Chance Rain Showers     18
# 9   Slight Chance Showers And Thunderstorms      3
# 10                                    Sunny     35

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Puzzle 3: Create a Scatter Plot
#
# Finally, let's create a scatter plot of your forecast!
#
# Using `df.plot.scatter`, you must specify the `x` column name and `y` column name for your scatter plot to use the command:
#
# ```
# df.plot.scatter(x="x-column", y="y-column")
# ```
#
# Using your weather forecast:
#
# - Use the starting date of the forecast as your `x` value,
# - Use the temperature as your `y` value,
# - Create your scatter plot! :)

# %%
df.plot.scatter(x = "startTime", y = "temperature")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='startTime', ylabel='temperature'>

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## 🔬 Microproject Checkpoint Tests 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for the microproject.
# - If this cell runs without any error in the output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cells, make changes, and RE-RUN your code and then this cell.
tada = "\N{PARTY POPPER}"

assert("/points/" in pointsJSON["id"])
assert(f"/{int(latitude)}" in pointsJSON["id"])
assert(f",{int(longitude)}" in pointsJSON["id"])
assert("/gridpoints/" in hourlyForecastURL)
assert("/forecast/hourly" in hourlyForecastURL)
print(f"{tada} Data API: All Tests Passed! {tada}")


assert("df" in vars())
assert("startTime" in df)
assert("temperature" in df)
print(f"{tada} Puzzle 1: All Tests Passed! {tada}")


assert( len(df_warmest) == 1 )
assert( df_warmest["temperature"].values[0] == max(df["temperature"]) )

assert( len(df_coldest) == 1 )
assert( df_coldest["temperature"].values[0] == min(df["temperature"]) )

assert( len(skySummary) == len(df["shortForecast"].unique()) )
pd.testing.assert_frame_equal(skySummary.sort_values("shortForecast").sort_values("count").set_index("shortForecast"), pd.DataFrame(df["shortForecast"].value_counts()).reset_index().rename({"index": "shortForecast", "shortForecast": "count"}, axis=1).sort_values("shortForecast").sort_values("count").set_index("shortForecast"))
print(f"{tada} Puzzle 2: All Tests Passed! {tada}")

print(f"{tada}{tada} All Tests Passed! {tada}{tada}")
# Out:
# 🎉 Data API: All Tests Passed! 🎉
# 🎉 Puzzle 1: All Tests Passed! 🎉
# 🎉 Puzzle 2: All Tests Passed! 🎉
# 🎉🎉 All Tests Passed! 🎉🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub and run the GitHub Actions Grader:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the instructions to commit and grade this MicroProject!
